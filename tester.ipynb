# %%
import spotify_client
from yt_dlp import YoutubeDL
import requests
from bs4 import BeautifulSoup
import urllib3
import numpy as np
from search_yt import searchyt
import re
import json
import certifi
from yt_downloader import yt_mp3_downloader

# %%
client_id ="fa83e0a148db4453b4d127e6b180133c"
client_secret = "8021ee89615e405f981b475a09eb8ab9"
playlist_link = "your playlist link"
local_path = r"the forlder where you want it downloaded"

downloader = yt_mp3_downloader(client_id=client_id, client_secret=client_secret, playlist_url=playlist_link, local_path=local_path)

downloader.download_global()
# Out:
# [youtube] naW6-WxmMiU: Downloading webpage
# [youtube] naW6-WxmMiU: Downloading android player API JSON
# [info] naW6-WxmMiU: Downloading 1 format(s): 251
# [download] Destination: C:\Users\Antonin\Documents\personal projects\music\yt_to_mp3\playlist\Dennis Lloyd - Nevermind (Official Video).webm
# [download] 100% of 2.60MiB in 00:00
# [ExtractAudio] Destination: C:\Users\Antonin\Documents\personal projects\music\yt_to_mp3\playlist\Dennis Lloyd - Nevermind (Official Video).mp3
# Deleting original file C:\Users\Antonin\Documents\personal projects\music\yt_to_mp3\playlist\Dennis Lloyd - Nevermind (Official Video).webm (pass -k to keep)
# [youtube] qke-jOUqSXU: Downloading webpage
# [youtube] qke-jOUqSXU: Downloading android player API JSON
# [info] qke-jOUqSXU: Downloading 1 format(s): 251
# [download] Destination: C:\Users\Antonin\Documents\personal projects\music\yt_to_mp3\playlist\Camelphat & Elderbrook ‘Cola’.webm
# [download] 100% of 7.05MiB in 00:00
# ...
